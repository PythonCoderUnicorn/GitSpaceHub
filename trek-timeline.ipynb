# %%
import pandas as pd

# %%
df = pd.read_csv("startrek-timeline.csv", usecols=[1, 2])
df
# Out:
#      Stardate                                        Description
# 0        2103                               Earth colonizes Mars
# 1   2156_2160                              The Earth–Romulan War
# 2        2161  The United Federation of Planets is founded by...
# 3        2165                       Sarek born (father of Spock)
# 4        2222              Montgomery Scott is born in Scotland.
# 5        2226                  Michael Burnham is born on Earth.
# 6        2227  Leonard McCoy is born in Georgia, North Americ...
# 7        2230  Spock, born on Vulcan., Hikaru Sulu is born in...
# 8        2233  James T. Kirk is born in Riverside, Iowa on Ea...
# 9        2245                                  Pavel Chekov born
# 10       2305  Jean-Luc Picard is born in LaBarre, France on ...
# 11       2324  Beverly Howard (Crusher) is born in Copernicus...
# 12       2332  Benjamin L. Sisko is born in New Orleans, Loui...
# ...
