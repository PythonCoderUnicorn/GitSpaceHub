# %%
import numpy as np
import pandas as pd

# %%
# categories >2 : train.Embarked.value_counts()
pd.get_dummies(starships.Size, prefix='Size')
starships.Size

starships['Starships_Size'] = starships.Size.map({'small':0, 
                                                  'medium':1, 
                                                  'large':2})
# starships.head()
# d = pd.get_dummies(starships.Size)
# print(d)
# type(starships.Size)

# print(starships.Starships_Size) 


# pd.get_dummies(starships.Electro_plasma, prefix='plasma')
# starships.Electro_plasma

# starships['Electro_plasma'] = starships.Electro_plasma.map({'No':0, 'Yes':1 })
# print(starships.Electro_plasma)

# starships.head()
# d = pd.get_dummies(starships.Electro_plasma)
# print('>>>',d)





large_Crew = np.random.randint(1,15,38)
small_Crew= np.random.randint(1,15,38)
medium_Crew= np.random.randint(16,200, 38)

# large_Crew_Capacity2 = np.random.randint(202,1150,38),
    
Crew_Size = [small_Crew[0], small_Crew[1], small_Crew[2], small_Crew[3],
             medium_Crew[0], small_Crew[4],
             small_Crew[5], medium_Crew[1], small_Crew[6], small_Crew[7], 
             small_Crew[8], small_Crew[9],
             small_Crew[10], small_Crew[11], small_Crew[12], small_Crew[13], 
             large_Crew[0], large_Crew[1],
             small_Crew[14], small_Crew[15], small_Crew[16], small_Crew[17], 
             medium_Crew[2], large_Crew[1],
             medium_Crew[3], small_Crew[18], small_Crew[19], small_Crew[20], 
             small_Crew[21], small_Crew[22],
             small_Crew[23], medium_Crew[4], medium_Crew[5], small_Crew[24], 
             small_Crew[25], small_Crew[26],
             medium_Crew[5], medium_Crew[6],
            ]
# Crew_Size



electroPlasma = np.random.randint(0,2, 38)
# electroPlasma

dilithium_matrix = np.random.uniform(low=0.1, high= 3.70, size=(38,))
# dilithium_matrix 

Warp_speed = np.random.uniform(low=1.5, high= 9.977, size=(38,))  
print('warp speed',Warp_speed)


Antimatter_Containment_Field = np.random.uniform(low=15.0, high=30.3, size=(38,)) 
# Antimatter_Containment_Field
# Out:
# warp speed [4.98545166 3.7321486  5.92226575 3.86075707 1.89774937 7.85704363
#  4.05452803 4.93461026 9.71211165 7.2587548  8.50325824 4.91054565
#  7.77598638 1.92526562 4.16265299 3.77818957 4.04382827 9.04802908
#  9.53589613 7.56564529 8.52015832 3.08498003 5.10942469 9.82308137
#  7.36552377 6.32274816 8.31232997 5.02096652 7.29726085 6.26013763
#  8.9701601  3.13245338 3.64124066 3.82221844 8.45589617 7.16340751
#  4.94690702 9.58014391]

# %%
starships = pd.DataFrame(
    {
        'Species': ['Acamarian','Akritirian','Aksani',
                    'Ankari','Annari','Antares (Corvallen)', 'Arkonian','Assault','Axanar',"'B'omar" ,"Ba'Neth","Ba'ul",\
                    'Antares','Benthan','Boslic','Breen','Caatati','Dauntless','Devore','Gorn','Hazari','Hierarchy',\
                    'Kaplan F17','Kraylor','Lokirrim','Lysian*','Maquis','Mazarite','Nausicaan','Numiri',"Onquanii\'s","Penk\'s",\
                    'Pralor','Rakosan','Ramuran','Retellian','Tamarian','Zalkonian',
                   ],
        'Type': ['starship', 'cargo freighter','starship',
                'starship','warship (2372),(2377)','freighter', 'military vessel','starship','cargo freighter','patrol ship','starship','attack fighter','starship','fighter','cargo', 'vessel', 'starship', 'starship','warship','vessel', 'starship','starship','Freighter','medical transport','patrol ship','attack vessels','raider','starship', 'freighter','patrol','starship','starship','starship','fighter', 'starship','freighter', 'cruiser','warship', 
                ],
        'Size': ['small','small','small','small', 'medium','small',\
               'small','medium','small','small','small', 'small', \
               'small', 'small','small','medium', 'large','large', 
               'small', 'small', 'small','small', 'medium','large',\
               'medium','small', 'small', 'small','small', 'small',\
               'small', 'medium', 'medium', 'small','small','small', 
               'medium','medium',],
        'Crew_Size': Crew_Size,
        'Starship_Size': starships.Starships_Size,
        'Electro_plasma': electroPlasma,
        'Warp_speed': Warp_speed,
        'Anti_Contain_Field': Antimatter_Containment_Field,
        'Dilithium_matrix': dilithium_matrix,
        'Armament': ['Phasers','Null','Phasers', 'Null',  '"pulses" to illuminate cloaked vessels.',
                    'Null', 'Null','Phasers','Null','Null','directed energy weapons and torpedoes','Null', 'directed energy weaponry.', 'Null', 'phasers and tractor beams','Null','energy dissipators','Null','phasers','Null','2+ phaser emitters','Directed energy weapons, spatial charges','Polaron-based directed energy weapons and torpedos','Phasers, Photon torpedoes','Phasers','Phasers, photonic disruptor','Null*','2+ phaser banks, 4 torpedo launchers','Directed energy weapons','Plasma cannons', 'Directed energy weapons','weapons and shields', 'Neutronic weaponry, dampening field','Quantum resonance charges','single directed energy weapon','proton weapons','Particle beam weapons','Phasers', 
                    ],
        'Defenses': [ 'Deflector shields','trilithium explosives', 'Deflector shields',
                    'Null','cloaking device','Cloaking field, deflector shields','Hull: tritanium and disilicon polymers.','shields','cloaking','Null','Null','Null','Null','torpedo weapons','Null','shields','refractive shielding','deflector screen','Deflector shields','Auto-regenerative shielding','Deflector shields','Deflector shields, cloaking device','Deflector shields','Deflector shields','Deflector shields','Deflector shields','Shields','Regenerative shields','subspace audio communications, cloaking device, and featured advanced transporter functions','Reinforced hull plating, covariant shields, multiphasic force fields','Subspace defense field','missiles with plasma wave',\
                     'cloaking devices','Null','Deflector shields','Deflector shields','Null_',"Null_"
                    ],
#         'ship_weight_kg': np.random.randint(119e3, 420e3,38),
#         'small_Crew_Capacity': np.random.randint(1,15,38),
#         'medium_Crew_Capacity': np.random.randint(16,200, 38),
#         'large_Crew_Capacity': np.random.randint(202,1150,38),
        
        
    },
    columns = ['Species','Type','Size','Starship_Size','Crew_Size',\
               'Electro_plasma','Dilithium_matrix','Anti_Contain_Field',\
               'Warp_speed','Armament','Defenses',
               
              ]# 'Starship_Size',
)
# starships
# Out:
#                 Species                   Type    Size  Starship_Size  \
# 0             Acamarian               starship   small              0
# 1            Akritirian        cargo freighter   small              0
# 2                Aksani               starship   small              0
# 3                Ankari               starship   small              0
# 4                Annari  warship (2372),(2377)  medium              1
# 5   Antares (Corvallen)              freighter   small              0
# 6              Arkonian        military vessel   small              0
# 7               Assault               starship  medium              1
# 8                Axanar        cargo freighter   small              0
# 9               'B'omar            patrol ship   small              0
# 10              Ba'Neth               starship   small              0
# 11                Ba'ul         attack fighter   small              0
# ...

# %% [raw]
# • Impulse drive • Nacelle • Spore drive • Warp core • Warp factor
#
#
#
# #-------- warp drive / hyperdrive
# - warp engines were fueled by the reaction of matter (deuterium) and antimatter (antideuterium), mediated through an assembly of dilithium crystals
# - nonreactive with antimatter when subjected to high-frequency electromagnetic fields. This reaction produced a highly energetic plasma, called electro-plasma or warp plasma, which was channeled by plasma conduits through the electro-plasma system (EPS) {ship's energy supply}
# - propulsion the electro-plasma was funneled by plasma injectors into a series of warp field coils, usually located in remote warp nacelles. These coils were composed of verterium cortenide and generated the warp field.
#
#
#
#
# #------ propulsion tech
# Dilithium matrix
# - key components in a warp drive.
# - matrix must be aligned within 0.3 microns
# - destabilized = unable to use its warp drive.
# -  phase lock the plasma injectors to the dilithium matrix, as the plasma flow in the manifold was constricted.
# - dilithium matrix realigned to a frequency of 3.69
#
# dilithium_mtrix = np.random.uniform(low=0.1, high= 3.70, size=(38,))
#
#
#
# #------ Parts of the system (warp drive)
# Antimatter containment
#     - Antimatter containment was the process whereby antimatter and matter were kept separated by the use of magnetic fields to prevent the oppositely charged particles from colliding, which would result in the mutual destruction of the matter and antimatter, along with a violent and explosive release of pure energy according to Einstein's formula E=mc2
#     - If the antimatter containment field strength dropped below 15% on a Galaxy-class starship, the field would collapse, causing a warp core breach and destroying the ship.
#
# antimatter_contain_field = np.random.uniform(low=15.0, high=30.3, size=(38,))
# antimatter_contain_field
#
#
# Antimatter inducer
# Antimatter relay
# Deuterium cartridges
# Deuterium control conduit
# Electro-plasma
#     - high-power mechanics, electro-plasma was a super-energized plasma used to transfer energy from a central power source using plasma conduit transfer. Extremely high-powered warp plasma, drive plasma, or magnetic plasma was used as a plasma stream to power the warp drive of a starship.
#     - On Federation starships and outposts, as well as those of other major spacefaring species, electro-plasma was the main power transfer medium.
#
#
#
#
#
# Emergency shutdown trips
# Main stage flux chiller
# Magnetic interlock
# Nacelle
#     - Bussard collectors
#     - Plasma injector
#     - Warp coil
#
# Nullifier core
# Pre stage flux chiller
# Phase inducer
# Plasma conduit
# Plasma intercooler
#     - Plasma coolant
# Plasma regulator
# Power transfer conduit
# Power transfer grid
# Space matrix restoration coil
# Warp field generator
# Warp plasma conduit
# Warp core / matter/antimatter reaction assembly
#     - Antimatter injector
#     - Antiproton injection seal
#     - Dilithium crystal chamber
#     - dilithium articulation frame
#     - dilithium chamber hatch
#     - dilithium crystal
#     - dilithium regulator
#     - Intermix chamber
#     - Matter injector/deuterium injector
#     - Theta-matrix compositor
#
#
#
# #------ System types
# Class 7 warp drive
# Class 9 warp drive
# Enhanced warp drive
# S-2 graf unit
# Subspace resonator
# Tetryon plasma warp drive
# Tricyclic plasma drive
# Warp five engine
# Warp three engine
# Yoyodyne pulse fusion
#
#
# Maximum speed:
# #---------
# Vulcans were an interstellar civilization by 9th century BC and had reached the level of warp 7 by 2151.
#
# Klingons had interstellar travel capability around the time of Kahless in the 9th century. achieved the capability of warp 6 by 2151.
#
# Vissians developed warp drive around the 12th century.
#
# Borg in the Delta Quadrant began to establish their interstellar collective by the 15th century.
#
# (maxing out at warp 4.7), the starship finally reached warp 5 on February 9, 2152
# 2161, Starfleet warp drive technology had achieved the capability to reach warp 7
# 2240s, Starfleet vessels speeds of warp 6 and emergency speeds as high as warp 8
# USS Enterprise was modified by the Kelvans to maintain a speed of warp 11 in 2268.
# 2269 Enterprise accelerated to a speed of warp factor 14.1
# ----- 24th century, a new warp factor scale came into use, which placed warp 10 as a theoretical maximum
# 2360s, warp technology had progressed to the point where speeds of warp 9.6 could be sustained for up to twelve hours, although warp 9.2 was considered the "red line."
# 2367, the warp drive on the Galaxy-class starship was managed by the warp propulsion power system.
# USS Voyager was capable of a top cruising speed of warp 9.975
# 2372, that the transwarp threshold was broken by the Federation managed to achieve infinite velocity on the shuttlecraft Cochrane.
#
#
# #------- shuttlepods registry number 01 to 15
#
# #-- shuttle weight = 261600 (lbs.) | 118659.8 kg
#
# #---- SPACE STATION ------------
# Fully crewed: 7
# Mass: 419,725 kg
# Orbital speed:	7.66 km/s (27,600 km/h)
#
#
#
#
# #------ engine sizes
# - 2+ ton dry weight engine
# - thrust of up to 1,500 N,
# - generator output is 750 W
# - 1,050 shp / 783 kW
# #----- power/mass (kW/kg)
# power_mass = [0.28, ]
#
#
#
# # https://en.wikipedia.org/wiki/List_of_heaviest_spacecraft
# #----- mass (kg)
# (lightest to heaviest spacecraft: kg): [7,000 : 541128 ]
#
# #----- capacity_crew
# 'Capacity': [1:1015]
#
# #---- number of crew
# #https://memory-alpha.fandom.com/wiki/VOY_regular_cast_non-appearances
#
# TNG: 1,014 members of the ship's complement
# TNG: 27 main crew members
# DS9: 10: [Avery Brooks, Nana Visitor, Rene Auberjonois, Michael Dorn, Terry Farrell, Alexander Siddig, Colm Meaney, Nicole de Boer, Armin Shimerman, Cirroc Lofton],
# VOY: 10: [Kate Mulgrew,Robert Beltran,Tim Russ,Robert Duncan McNeill,Roxann Dawson,Garrett Wang,Robert Picardo,Ethan Phillips,Jeri Ryan,Jennifer Lien]

# %% [raw]
# # https://memory-alpha.fandom.com/wiki/Diagnostic_mode
# # https://memory-alpha.fandom.com/wiki/Type_15_shuttlepod
# import numpy as np
# import pandas as pd
#
# large_Crew = np.random.randint(119e3, 420e3,38)
# small_Crew= np.random.randint(1,15,38)
# medium_Crew= np.random.randint(16,200, 38)
#
# # large_Crew_Capacity2 = np.random.randint(202,1150,38),
#
# #  small_Crew,  medium_Crew,  large_Crew,
# Crew_Size = [small_Crew, small_Crew, small_Crew, small_Crew, medium_Crew, small_Crew,
#              small_Crew, medium_Crew, small_Crew, small_Crew, small_Crew, small_Crew,
#              small_Crew, small_Crew, small_Crew, small_Crew, large_Crew, large_Crew,
#              small_Crew, small_Crew, small_Crew, small_Crew, medium_Crew, large_Crew,
#              medium_Crew, small_Crew, small_Crew, small_Crew, small_Crew, small_Crew,
#              small_Crew, medium_Crew, medium_Crew, small_Crew, small_Crew, small_Crew,
#              medium_Crew, medium_Crew,
#             ]
#
#
# # print(len(Species))
# # print(len(Type))
# # print(len(Size))
# # print(len(ship_weight_kg))
# print(len(large_Crew))
# print(len(small_Crew))
# print(len(medium_Crew))
# # print(len(large_Crew_Capacity2))

# %%
df = pd.read_csv('startrek_shuttles.csv')
df.head()
# Out:
#       Species                   Type    Size  Starship_Size  Crew_Size  \
# 0   Acamarian               starship   small              0         11
# 1  Akritirian        cargo freighter   small              0          7
# 2      Aksani               starship   small              0          4
# 3      Ankari               starship   small              0          9
# 4      Annari  warship (2372),(2377)  medium              1         81
#
#    Electro_plasma  Dilithium_matrix  Anti_Contain_Field  Warp_speed  \
# 0               0          0.716718           17.685763    4.985452
# 1               0          1.959474           17.820311    3.732149
# 2               0          0.531512           23.000933    5.922266
# 3               1          2.730029           16.152038    3.860757
# 4               0          0.999517           17.220668    1.897749
#
#                                   Armament               Defenses
# ...
